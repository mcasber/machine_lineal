# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Mariano\\Desktop\\WebScraping\\files\\df_final.csv')
df.head(3)
# Out:
#    precio    uva  dia  mes  ano  decena_1  decena_2  decena_3  tri_1  tri_2  \
# 0     955  463.0    2    1   24         1         0         0      1      0
# 1    1205  525.0   24    1   24         0         0         1      1      0
# 2    1165  561.0    1    2   24         1         0         0      1      0
#
#    tri_3     precio2  abs_diferencia  porcentual_desvio
# 0      0  898.955780       56.044220           0.058685
# 1      0  994.421530      210.578470           0.174754
# 2      0  963.711676      201.288324           0.172780

# %%
df.describe().round(4)
# Out:
#           precio        uva      dia      mes   ano  decena_1  decena_2  \
# count    98.0000    98.0000  98.0000  98.0000  98.0   98.0000   98.0000
# mean   1276.9388   995.8445  15.1429   6.0306  24.0    0.3776    0.2857
# std     143.7363   124.7788   9.3610   1.5159   0.0    0.4873    0.4541
# min     955.0000   463.0000   1.0000   1.0000  24.0    0.0000    0.0000
# 25%    1206.2500   978.7500   7.2500   5.0000  24.0    0.0000    0.0000
# 50%    1297.5000  1030.0000  14.5000   6.0000  24.0    0.0000    0.0000
# 75%    1395.0000  1071.6025  24.0000   7.0000  24.0    1.0000    1.0000
# max    1480.0000  1111.5800  31.0000   8.0000  24.0    1.0000    1.0000
#
#        decena_3    tri_1    tri_2  tri_3    precio2  abs_diferencia  \
# count   98.0000  98.0000  98.0000   98.0    98.0000         98.0000
# mean     0.3367   0.0816   0.4796    0.0  1278.5966         52.5703
# std      0.4750   0.2752   0.5022    0.0   125.0089         43.2811
# ...

# %%
df.porcentual_desvio.plot()
# Out:
# <AxesSubplot: >
