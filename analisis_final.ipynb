# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Mariano\\Desktop\\WebScraping\\files\\df_final.csv')
df.head(3)
# Out:
#    precio    uva  dia  mes  ano  decena_1  decena_2  decena_3  tri_1  tri_2  \
# 0     955  463.0    2    1   24         1         0         0      1      0
# 1    1205  525.0   24    1   24         0         0         1      1      0
# 2    1165  561.0    1    2   24         1         0         0      1      0
#
#    tri_3     precio2  abs_diferencia  porcentual_desvio
# 0      0  893.741080       61.258920           0.064145
# 1      0  994.416533      210.583467           0.174758
# 2      0  958.181457      206.818543           0.177527

# %%
df.describe().round(4)
# Out:
#           precio        uva      dia      mes   ano  decena_1  decena_2  \
# count    96.0000    96.0000  96.0000  96.0000  96.0   96.0000   96.0000
# mean   1275.7812   993.4835  15.1979   5.9896  24.0    0.3854    0.2708
# std     145.0124   124.9856   9.4508   1.5043   0.0    0.4892    0.4467
# min     955.0000   463.0000   1.0000   1.0000  24.0    0.0000    0.0000
# 25%    1205.0000   977.2500   7.0000   5.0000  24.0    0.0000    0.0000
# 50%    1282.5000  1030.0000  15.0000   6.0000  24.0    0.0000    0.0000
# 75%    1396.2500  1069.2700  24.0000   7.0000  24.0    1.0000    1.0000
# max    1480.0000  1106.7600  31.0000   8.0000  24.0    1.0000    1.0000
#
#        decena_3    tri_1    tri_2  tri_3    precio2  abs_diferencia  \
# count   96.0000  96.0000  96.0000   96.0    96.0000         96.0000
# mean     0.3438   0.0833   0.4896    0.0  1276.9885         52.0423
# std      0.4775   0.2778   0.5025    0.0   128.6713         43.0051
# ...

# %%
df.porcentual_desvio.plot()
# Out:
# <AxesSubplot: >
